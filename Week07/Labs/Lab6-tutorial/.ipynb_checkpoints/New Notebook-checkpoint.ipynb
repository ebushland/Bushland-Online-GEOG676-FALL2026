# %%
import arcpy

# %%
aprx = arcpy.mp.ArcGISProject("CURRENT")

# %%
m = aprx.listMaps()[0]

# %%
hillshade_path = r"C:\Users\ebush\Desktop\TexasAM\GEOG-676\Week7\Lab6-tutorial\Lab6-tutorial.gdb\tx_hillshade"

# %%
result = arcpy.management.MakeRasterLayer(hillshade_path, "tx_hillshade_layer")

# %%
m.addLayer(result.getOutput(0))
